# %%
import numpy as np
from sklearn import svm, metrics
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, MaxPool2D, Flatten, Dense, Dropout
from tensorflow.keras.models import Sequential
from tensorflow import keras
from keras.utils import to_categorical
from keras.optimizers import Adam
from keras.preprocessing.image import img_to_array, array_to_img
from skimage.transform import resize, rescale
import matplotlib.pyplot as plt
from skimage import data, color
from PIL import Image
import cv2
from numpy import savez_compressed
from google.colab import files
from numpy import load
from sklearn.model_selection import KFold
from keras.callbacks import EarlyStopping
from google.colab import drive
drive.mount('/content/gdrive')

filename = '/content/gdrive/My Drive/Research2/np_data/xkmnist.npz'
x = np.load(filename)['arr_0']

filename = '/content/gdrive/My Drive/Research2/np_data/ykmnist.npz'
y = np.load(filename)['arr_0']

print(x.shape)
print(y.shape)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# (70000, 56, 56, 1)
# (70000, 1)

# %%
baseAccuracies = []
losses = []
balancedAccuracies = []
f1scores = []
precisions = []
recalls = []

kfold = KFold(n_splits=10, shuffle=True)
fold_no = 1
callback = EarlyStopping(monitor = 'val_loss', patience = 2, verbose = 1)

for train, test in kfold.split(x, y):
  print("_________________________________________________________________________________________________________________________________")
  print("Fold number: " + str(fold_no))
  fold_no = fold_no+1
  print()

  xtrain = x[train]
  xtest = x[test]
  
  model = tf.keras.applications.VGG16(include_top=True, weights=None, input_shape=(56, 56, 1), classes=10, classifier_activation="softmax",)
  model.compile(loss="sparse_categorical_crossentropy", optimizer=Adam(lr=0.0001), metrics=["sparse_categorical_accuracy"])
  model.fit(xtrain, y[train], verbose = 1, validation_data = (xtest, y[test]), epochs = 100, callbacks = [callback], batch_size = 32)

  test_loss, test_accuracy = model.evaluate(xtest, y[test])
  print("_________________________________________________________________________________________________________________________________")
  print("Test Accuracy:")
  print(test_accuracy)
  baseAccuracies.append(test_accuracy)
  print("_________________________________________________________________________________________________________________________________")
  print("Test Loss:")
  print(test_loss)
  losses.append(test_loss)
  print("_________________________________________________________________________________________________________________________________")
  preds = np.argmax(model.predict(xtest), axis=-1)
  preds = preds.reshape(len(xtest), 1)
  accs = []
  for cls in range(10):
    mask = (y[test] == cls)
    cls_acc = (preds == cls)[mask].mean() 
    accs.append(cls_acc)
  accs = np.mean(accs)
  print("Final balanced accuracy:")
  print(accs)
  balancedAccuracies.append(accs)
  print("_________________________________________________________________________________________________________________________________")
  f1scores.append(f1_score(y[test], preds, average = 'weighted'))
  precisions.append(precision_score(y[test], preds, average = 'weighted'))
  recalls.append(recall_score(y[test], preds, average = 'weighted'))
  print("*********************************************************************************************************************************")
  print()
  print()
# Out:
# _________________________________________________________________________________________________________________________________
# Fold number: 1
#
# Epoch 1/100
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.3296 - sparse_categorical_accuracy: 0.8934 - val_loss: 0.1045 - val_sparse_categorical_accuracy: 0.9654
# Epoch 2/100
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.0788 - sparse_categorical_accuracy: 0.9776 - val_loss: 0.0641 - val_sparse_categorical_accuracy: 0.9826
# Epoch 3/100
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.0522 - sparse_categorical_accuracy: 0.9857 - val_loss: 0.0753 - val_sparse_categorical_accuracy: 0.9819
# Epoch 4/100
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.0389 - sparse_categorical_accuracy: 0.9895 - val_loss: 0.0574 - val_sparse_categorical_accuracy: 0.9843
# Epoch 5/100
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.0280 - sparse_categorical_accuracy: 0.9925 - val_loss: 0.0441 - val_sparse_categorical_accuracy: 0.9897
# Epoch 6/100
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.0248 - sparse_categorical_accuracy: 0.9933 - val_loss: 0.0338 - val_sparse_categorical_accuracy: 0.9911
# Epoch 7/100
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.0201 - sparse_categorical_accuracy: 0.9947 - val_loss: 0.0444 - val_sparse_categorical_accuracy: 0.9887
# Epoch 8/100
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.0173 - sparse_categorical_accuracy: 0.9954 - val_loss: 0.0587 - val_sparse_categorical_accuracy: 0.9881
# Epoch 00008: early stopping
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0587 - sparse_categorical_accuracy: 0.9881
# _________________________________________________________________________________________________________________________________
# Test Accuracy:
# 0.9881428480148315
# _________________________________________________________________________________________________________________________________
# Test Loss:
# 0.05873735621571541
# _________________________________________________________________________________________________________________________________
# Final balanced accuracy:
# 0.9881468688160926
# _________________________________________________________________________________________________________________________________
# *********************************************************************************************************************************
#
#
# _________________________________________________________________________________________________________________________________
# Fold number: 2
#
# Epoch 1/100
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.3507 - sparse_categorical_accuracy: 0.8851 - val_loss: 0.1067 - val_sparse_categorical_accuracy: 0.9690
# Epoch 2/100
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.0844 - sparse_categorical_accuracy: 0.9760 - val_loss: 0.0828 - val_sparse_categorical_accuracy: 0.9777
# Epoch 3/100
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.0553 - sparse_categorical_accuracy: 0.9842 - val_loss: 0.0642 - val_sparse_categorical_accuracy: 0.9820
# Epoch 4/100
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.0386 - sparse_categorical_accuracy: 0.9892 - val_loss: 0.0460 - val_sparse_categorical_accuracy: 0.9874
# Epoch 5/100
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.0325 - sparse_categorical_accuracy: 0.9911 - val_loss: 0.0444 - val_sparse_categorical_accuracy: 0.9876
# Epoch 6/100
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.0241 - sparse_categorical_accuracy: 0.9933 - val_loss: 0.0465 - val_sparse_categorical_accuracy: 0.9886
# Epoch 7/100
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.0189 - sparse_categorical_accuracy: 0.9949 - val_loss: 0.0440 - val_sparse_categorical_accuracy: 0.9883
# Epoch 8/100
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.0182 - sparse_categorical_accuracy: 0.9948 - val_loss: 0.0396 - val_sparse_categorical_accuracy: 0.9899
# Epoch 9/100
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.0147 - sparse_categorical_accuracy: 0.9959 - val_loss: 0.0481 - val_sparse_categorical_accuracy: 0.9900
# Epoch 10/100
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.0142 - sparse_categorical_accuracy: 0.9962 - val_loss: 0.0840 - val_sparse_categorical_accuracy: 0.9847
# Epoch 00010: early stopping
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0840 - sparse_categorical_accuracy: 0.9847
# _________________________________________________________________________________________________________________________________
# Test Accuracy:
# 0.9847142696380615
# _________________________________________________________________________________________________________________________________
# Test Loss:
# 0.08396435528993607
# _________________________________________________________________________________________________________________________________
# Final balanced accuracy:
# 0.9849593217240604
# _________________________________________________________________________________________________________________________________
# *********************************************************************************************************************************
#
#
# _________________________________________________________________________________________________________________________________
# Fold number: 3
#
# Epoch 1/100
#    1/1969 [..............................] - ETA: 0s - loss: 2.3026 - sparse_categorical_accuracy: 0.0312WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0107s vs `on_train_batch_end` time: 0.0163s). Check your callbacks.
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.3329 - sparse_categorical_accuracy: 0.8912 - val_loss: 0.1191 - val_sparse_categorical_accuracy: 0.9654
# Epoch 2/100
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.0798 - sparse_categorical_accuracy: 0.9769 - val_loss: 0.1058 - val_sparse_categorical_accuracy: 0.9726
# Epoch 3/100
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.0518 - sparse_categorical_accuracy: 0.9857 - val_loss: 0.0799 - val_sparse_categorical_accuracy: 0.9807
# Epoch 4/100
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.0385 - sparse_categorical_accuracy: 0.9892 - val_loss: 0.1006 - val_sparse_categorical_accuracy: 0.9756
# Epoch 5/100
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.0265 - sparse_categorical_accuracy: 0.9925 - val_loss: 0.0615 - val_sparse_categorical_accuracy: 0.9849
# Epoch 6/100
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.0232 - sparse_categorical_accuracy: 0.9933 - val_loss: 0.0528 - val_sparse_categorical_accuracy: 0.9883
# Epoch 7/100
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.0202 - sparse_categorical_accuracy: 0.9943 - val_loss: 0.0487 - val_sparse_categorical_accuracy: 0.9880
# Epoch 8/100
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.0143 - sparse_categorical_accuracy: 0.9960 - val_loss: 0.0538 - val_sparse_categorical_accuracy: 0.9870
# Epoch 9/100
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.0141 - sparse_categorical_accuracy: 0.9961 - val_loss: 0.0738 - val_sparse_categorical_accuracy: 0.9841
# Epoch 00009: early stopping
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0738 - sparse_categorical_accuracy: 0.9841
# _________________________________________________________________________________________________________________________________
# Test Accuracy:
# 0.9841428399085999
# _________________________________________________________________________________________________________________________________
# Test Loss:
# 0.07381614297628403
# _________________________________________________________________________________________________________________________________
# Final balanced accuracy:
# 0.9839666898704303
# _________________________________________________________________________________________________________________________________
# *********************************************************************************************************************************
#
#
# _________________________________________________________________________________________________________________________________
# Fold number: 4
#
# Epoch 1/100
#    1/1969 [..............................] - ETA: 0s - loss: 2.3026 - sparse_categorical_accuracy: 0.1250WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0106s vs `on_train_batch_end` time: 0.0161s). Check your callbacks.
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.3451 - sparse_categorical_accuracy: 0.8873 - val_loss: 0.0996 - val_sparse_categorical_accuracy: 0.9729
# Epoch 2/100
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.0831 - sparse_categorical_accuracy: 0.9761 - val_loss: 0.1049 - val_sparse_categorical_accuracy: 0.9709
# Epoch 3/100
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.0543 - sparse_categorical_accuracy: 0.9849 - val_loss: 0.0596 - val_sparse_categorical_accuracy: 0.9841
# Epoch 4/100
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.0390 - sparse_categorical_accuracy: 0.9889 - val_loss: 0.0428 - val_sparse_categorical_accuracy: 0.9881
# Epoch 5/100
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.0294 - sparse_categorical_accuracy: 0.9916 - val_loss: 0.0490 - val_sparse_categorical_accuracy: 0.9870
# Epoch 6/100
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.0250 - sparse_categorical_accuracy: 0.9930 - val_loss: 0.0437 - val_sparse_categorical_accuracy: 0.9890
# Epoch 00006: early stopping
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0437 - sparse_categorical_accuracy: 0.9890
# _________________________________________________________________________________________________________________________________
# Test Accuracy:
# 0.9890000224113464
# _________________________________________________________________________________________________________________________________
# Test Loss:
# 0.04366021603345871
# _________________________________________________________________________________________________________________________________
# Final balanced accuracy:
# 0.9889070631804865
# _________________________________________________________________________________________________________________________________
# *********************************************************************************************************************************
#
#
# _________________________________________________________________________________________________________________________________
# Fold number: 5
#
# Epoch 1/100
#    1/1969 [..............................] - ETA: 0s - loss: 2.3025 - sparse_categorical_accuracy: 0.1250WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0107s vs `on_train_batch_end` time: 0.0161s). Check your callbacks.
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.3354 - sparse_categorical_accuracy: 0.8885 - val_loss: 0.0930 - val_sparse_categorical_accuracy: 0.9709
# Epoch 2/100
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.0791 - sparse_categorical_accuracy: 0.9776 - val_loss: 0.0626 - val_sparse_categorical_accuracy: 0.9810
# Epoch 3/100
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.0527 - sparse_categorical_accuracy: 0.9850 - val_loss: 0.0603 - val_sparse_categorical_accuracy: 0.9851
# Epoch 4/100
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.0358 - sparse_categorical_accuracy: 0.9898 - val_loss: 0.0545 - val_sparse_categorical_accuracy: 0.9861
# Epoch 5/100
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.0293 - sparse_categorical_accuracy: 0.9922 - val_loss: 0.0554 - val_sparse_categorical_accuracy: 0.9841
# Epoch 6/100
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.0239 - sparse_categorical_accuracy: 0.9935 - val_loss: 0.0389 - val_sparse_categorical_accuracy: 0.9887
# Epoch 7/100
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.0200 - sparse_categorical_accuracy: 0.9947 - val_loss: 0.0567 - val_sparse_categorical_accuracy: 0.9853
# Epoch 8/100
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.0170 - sparse_categorical_accuracy: 0.9957 - val_loss: 0.0492 - val_sparse_categorical_accuracy: 0.9886
# Epoch 00008: early stopping
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0492 - sparse_categorical_accuracy: 0.9886
# _________________________________________________________________________________________________________________________________
# Test Accuracy:
# 0.9885714054107666
# _________________________________________________________________________________________________________________________________
# Test Loss:
# 0.04920338839292526
# _________________________________________________________________________________________________________________________________
# Final balanced accuracy:
# 0.9884877724805475
# _________________________________________________________________________________________________________________________________
# *********************************************************************************************************************************
#
#
# _________________________________________________________________________________________________________________________________
# Fold number: 6
#
# Epoch 1/100
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.3225 - sparse_categorical_accuracy: 0.8959 - val_loss: 0.1387 - val_sparse_categorical_accuracy: 0.9619
# Epoch 2/100
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.0784 - sparse_categorical_accuracy: 0.9775 - val_loss: 0.0773 - val_sparse_categorical_accuracy: 0.9781
# Epoch 3/100
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.0518 - sparse_categorical_accuracy: 0.9850 - val_loss: 0.0432 - val_sparse_categorical_accuracy: 0.9880
# Epoch 4/100
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.0373 - sparse_categorical_accuracy: 0.9897 - val_loss: 0.0664 - val_sparse_categorical_accuracy: 0.9839
# Epoch 5/100
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.0291 - sparse_categorical_accuracy: 0.9919 - val_loss: 0.0663 - val_sparse_categorical_accuracy: 0.9847
# Epoch 00005: early stopping
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0663 - sparse_categorical_accuracy: 0.9847
# _________________________________________________________________________________________________________________________________
# Test Accuracy:
# 0.9847142696380615
# _________________________________________________________________________________________________________________________________
# Test Loss:
# 0.06628632545471191
# _________________________________________________________________________________________________________________________________
# Final balanced accuracy:
# 0.9845279994441858
# _________________________________________________________________________________________________________________________________
# *********************************************************************************************************************************
#
#
# _________________________________________________________________________________________________________________________________
# Fold number: 7
#
# Epoch 1/100
#    1/1969 [..............................] - ETA: 0s - loss: 2.3026 - sparse_categorical_accuracy: 0.0938WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0105s vs `on_train_batch_end` time: 0.0161s). Check your callbacks.
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.3663 - sparse_categorical_accuracy: 0.8777 - val_loss: 0.1107 - val_sparse_categorical_accuracy: 0.9663
# Epoch 2/100
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.0865 - sparse_categorical_accuracy: 0.9753 - val_loss: 0.0926 - val_sparse_categorical_accuracy: 0.9756
# Epoch 3/100
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.0521 - sparse_categorical_accuracy: 0.9847 - val_loss: 0.0655 - val_sparse_categorical_accuracy: 0.9819
# Epoch 4/100
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.0389 - sparse_categorical_accuracy: 0.9889 - val_loss: 0.0558 - val_sparse_categorical_accuracy: 0.9839
# Epoch 5/100
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.0295 - sparse_categorical_accuracy: 0.9921 - val_loss: 0.0360 - val_sparse_categorical_accuracy: 0.9910
# Epoch 6/100
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.0240 - sparse_categorical_accuracy: 0.9933 - val_loss: 0.0335 - val_sparse_categorical_accuracy: 0.9906
# Epoch 7/100
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.0216 - sparse_categorical_accuracy: 0.9941 - val_loss: 0.0443 - val_sparse_categorical_accuracy: 0.9894
# Epoch 8/100
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.0165 - sparse_categorical_accuracy: 0.9955 - val_loss: 0.0446 - val_sparse_categorical_accuracy: 0.9894
# Epoch 00008: early stopping
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0446 - sparse_categorical_accuracy: 0.9894
# _________________________________________________________________________________________________________________________________
# Test Accuracy:
# 0.9894285798072815
# _________________________________________________________________________________________________________________________________
# Test Loss:
# 0.04460843279957771
# _________________________________________________________________________________________________________________________________
# Final balanced accuracy:
# 0.9892606856497546
# _________________________________________________________________________________________________________________________________
# *********************************************************************************************************************************
#
#
# _________________________________________________________________________________________________________________________________
# Fold number: 8
#
# Epoch 1/100
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.3475 - sparse_categorical_accuracy: 0.8878 - val_loss: 0.1295 - val_sparse_categorical_accuracy: 0.9633
# Epoch 2/100
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.0807 - sparse_categorical_accuracy: 0.9767 - val_loss: 0.0710 - val_sparse_categorical_accuracy: 0.9784
# Epoch 3/100
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.0528 - sparse_categorical_accuracy: 0.9853 - val_loss: 0.0619 - val_sparse_categorical_accuracy: 0.9820
# Epoch 4/100
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.0401 - sparse_categorical_accuracy: 0.9890 - val_loss: 0.0605 - val_sparse_categorical_accuracy: 0.9863
# Epoch 5/100
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.0301 - sparse_categorical_accuracy: 0.9921 - val_loss: 0.0650 - val_sparse_categorical_accuracy: 0.9841
# Epoch 6/100
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.0242 - sparse_categorical_accuracy: 0.9936 - val_loss: 0.0495 - val_sparse_categorical_accuracy: 0.9870
# Epoch 7/100
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.0179 - sparse_categorical_accuracy: 0.9948 - val_loss: 0.0535 - val_sparse_categorical_accuracy: 0.9867
# Epoch 8/100
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.0167 - sparse_categorical_accuracy: 0.9956 - val_loss: 0.0621 - val_sparse_categorical_accuracy: 0.9879
# Epoch 00008: early stopping
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0621 - sparse_categorical_accuracy: 0.9879
# _________________________________________________________________________________________________________________________________
# Test Accuracy:
# 0.9878571629524231
# _________________________________________________________________________________________________________________________________
# Test Loss:
# 0.06214045360684395
# _________________________________________________________________________________________________________________________________
# Final balanced accuracy:
# 0.9878680106976644
# _________________________________________________________________________________________________________________________________
# *********************************************************************************************************************************
#
#
# _________________________________________________________________________________________________________________________________
# Fold number: 9
#
# Epoch 1/100
#    1/1969 [..............................] - ETA: 0s - loss: 2.3026 - sparse_categorical_accuracy: 0.0625WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0108s vs `on_train_batch_end` time: 0.0165s). Check your callbacks.
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.3270 - sparse_categorical_accuracy: 0.8938 - val_loss: 0.0953 - val_sparse_categorical_accuracy: 0.9716
# Epoch 2/100
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.0791 - sparse_categorical_accuracy: 0.9779 - val_loss: 0.0753 - val_sparse_categorical_accuracy: 0.9787
# Epoch 3/100
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.0512 - sparse_categorical_accuracy: 0.9853 - val_loss: 0.0617 - val_sparse_categorical_accuracy: 0.9859
# Epoch 4/100
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.0365 - sparse_categorical_accuracy: 0.9899 - val_loss: 0.0623 - val_sparse_categorical_accuracy: 0.9827
# Epoch 5/100
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.0288 - sparse_categorical_accuracy: 0.9920 - val_loss: 0.0498 - val_sparse_categorical_accuracy: 0.9867
# Epoch 6/100
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.0234 - sparse_categorical_accuracy: 0.9937 - val_loss: 0.0451 - val_sparse_categorical_accuracy: 0.9880
# Epoch 7/100
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.0191 - sparse_categorical_accuracy: 0.9949 - val_loss: 0.0455 - val_sparse_categorical_accuracy: 0.9886
# Epoch 8/100
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.0188 - sparse_categorical_accuracy: 0.9951 - val_loss: 0.0518 - val_sparse_categorical_accuracy: 0.9894
# Epoch 00008: early stopping
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0518 - sparse_categorical_accuracy: 0.9894
# _________________________________________________________________________________________________________________________________
# Test Accuracy:
# 0.9894285798072815
# _________________________________________________________________________________________________________________________________
# Test Loss:
# 0.05183548107743263
# _________________________________________________________________________________________________________________________________
# Final balanced accuracy:
# 0.9894416314929098
# _________________________________________________________________________________________________________________________________
# *********************************************************************************************************************************
#
#
# _________________________________________________________________________________________________________________________________
# Fold number: 10
#
# Epoch 1/100
#    1/1969 [..............................] - ETA: 0s - loss: 2.3026 - sparse_categorical_accuracy: 0.0938WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0104s vs `on_train_batch_end` time: 0.0165s). Check your callbacks.
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.3289 - sparse_categorical_accuracy: 0.8937 - val_loss: 0.1245 - val_sparse_categorical_accuracy: 0.9636
# Epoch 2/100
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.0768 - sparse_categorical_accuracy: 0.9780 - val_loss: 0.0786 - val_sparse_categorical_accuracy: 0.9800
# Epoch 3/100
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.0514 - sparse_categorical_accuracy: 0.9857 - val_loss: 0.0705 - val_sparse_categorical_accuracy: 0.9816
# Epoch 4/100
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.0377 - sparse_categorical_accuracy: 0.9895 - val_loss: 0.0379 - val_sparse_categorical_accuracy: 0.9884
# Epoch 5/100
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.0262 - sparse_categorical_accuracy: 0.9927 - val_loss: 0.0558 - val_sparse_categorical_accuracy: 0.9873
# Epoch 6/100
# 1969/1969 [==============================] - 55s 28ms/step - loss: 0.0254 - sparse_categorical_accuracy: 0.9930 - val_loss: 0.0534 - val_sparse_categorical_accuracy: 0.9879
# Epoch 00006: early stopping
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0534 - sparse_categorical_accuracy: 0.9879
# _________________________________________________________________________________________________________________________________
# Test Accuracy:
# 0.9878571629524231
# _________________________________________________________________________________________________________________________________
# Test Loss:
# 0.05338968709111214
# _________________________________________________________________________________________________________________________________
# Final balanced accuracy:
# 0.9879797742857177
# _________________________________________________________________________________________________________________________________
# *********************************************************************************************************************************

# %%
print('------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(balancedAccuracies)):
  print('------------------------------------------------------------------------')
  print(f'> Fold {i+1} - Loss: {losses[i]} - class-wise Accuracy: {balancedAccuracies[i]}% Accuracy - {baseAccuracies[i]} - Precision: {precisions[i]} - Recall: {recalls[i]} - F1: {f1scores[i]}')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> Accuracy: {np.mean(balancedAccuracies)} (+- {np.std(balancedAccuracies)})')
print(f'> Loss: {np.mean(losses)}')
print('------------------------------------------------------------------------')
# Out:
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 0.05873735621571541 - class-wise Accuracy: 0.9881468688160926% Accuracy - 0.9881428480148315 - Precision: 0.9882471002671799 - Recall: 0.9881428571428571 - F1: 0.9881514540458786
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 0.08396435528993607 - class-wise Accuracy: 0.9849593217240604% Accuracy - 0.9847142696380615 - Precision: 0.9850322510289353 - Recall: 0.9847142857142858 - F1: 0.984678167996113
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 0.07381614297628403 - class-wise Accuracy: 0.9839666898704303% Accuracy - 0.9841428399085999 - Precision: 0.9842716651733878 - Recall: 0.9841428571428571 - F1: 0.984140979464737
# ------------------------------------------------------------------------
# > Fold 4 - Loss: 0.04366021603345871 - class-wise Accuracy: 0.9889070631804865% Accuracy - 0.9890000224113464 - Precision: 0.9890517900967832 - Recall: 0.989 - F1: 0.9890016723215258
# ------------------------------------------------------------------------
# > Fold 5 - Loss: 0.04920338839292526 - class-wise Accuracy: 0.9884877724805475% Accuracy - 0.9885714054107666 - Precision: 0.9885931108960029 - Recall: 0.9885714285714285 - F1: 0.9885653897398105
# ------------------------------------------------------------------------
# > Fold 6 - Loss: 0.06628632545471191 - class-wise Accuracy: 0.9845279994441858% Accuracy - 0.9847142696380615 - Precision: 0.9849644442584851 - Recall: 0.9847142857142858 - F1: 0.9847286425886694
# ------------------------------------------------------------------------
# > Fold 7 - Loss: 0.04460843279957771 - class-wise Accuracy: 0.9892606856497546% Accuracy - 0.9894285798072815 - Precision: 0.9895595227484514 - Recall: 0.9894285714285714 - F1: 0.9894166583851314
# ------------------------------------------------------------------------
# > Fold 8 - Loss: 0.06214045360684395 - class-wise Accuracy: 0.9878680106976644% Accuracy - 0.9878571629524231 - Precision: 0.9879169416619296 - Recall: 0.9878571428571429 - F1: 0.9878670856066979
# ------------------------------------------------------------------------
# > Fold 9 - Loss: 0.05183548107743263 - class-wise Accuracy: 0.9894416314929098% Accuracy - 0.9894285798072815 - Precision: 0.9894548712878829 - Recall: 0.9894285714285714 - F1: 0.989425957316069
# ------------------------------------------------------------------------
# > Fold 10 - Loss: 0.05338968709111214 - class-wise Accuracy: 0.9879797742857177% Accuracy - 0.9878571629524231 - Precision: 0.9879175916999354 - Recall: 0.9878571428571429 - F1: 0.9878572494805798
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 0.9873545817641849 (+- 0.0019537188085038755)
# > Loss: 0.05876418389379978
# ------------------------------------------------------------------------

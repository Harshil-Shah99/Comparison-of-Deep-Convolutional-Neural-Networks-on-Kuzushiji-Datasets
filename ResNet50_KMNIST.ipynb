# %%
import numpy as np
from sklearn import svm, metrics
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, MaxPool2D, Flatten, Dense, Dropout
from tensorflow.keras.models import Sequential
from tensorflow import keras
from keras.utils import to_categorical
from keras.optimizers import Adam
from keras.preprocessing.image import img_to_array, array_to_img
from skimage.transform import resize, rescale
import matplotlib.pyplot as plt
from skimage import data, color
from PIL import Image
import cv2
from numpy import savez_compressed
from google.colab import files
from numpy import load
from sklearn.model_selection import KFold
from keras.callbacks import EarlyStopping
from google.colab import drive
drive.mount('/content/gdrive')

filename = '/content/gdrive/My Drive/Research2/np_data/xkmnist.npz'
x = np.load(filename)['arr_0']

filename = '/content/gdrive/My Drive/Research2/np_data/ykmnist.npz'
y = np.load(filename)['arr_0']

print(x.shape)
print(y.shape)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# (70000, 56, 56, 1)
# (70000, 1)

# %%
baseAccuracies = []
losses = []
balancedAccuracies = []
f1scores = []
precisions = []
recalls = []

kfold = KFold(n_splits=10, shuffle=True)
fold_no = 1
callback = EarlyStopping(monitor = 'val_loss', patience = 2, verbose = 1)

for train, test in kfold.split(x, y):
  print("_________________________________________________________________________________________________________________________________")
  print("Fold number: " + str(fold_no))
  fold_no = fold_no+1
  print()

  xtrain = x[train]
  xtest = x[test]
  
  model = tf.keras.applications.ResNet50(include_top=True, weights=None, input_shape=(56, 56, 1), classes=10, classifier_activation="softmax",)
  model.compile(loss="sparse_categorical_crossentropy", optimizer=Adam(lr=0.0001), metrics=["sparse_categorical_accuracy"])
  model.fit(xtrain, y[train], verbose = 1, validation_data = (xtest, y[test]), epochs = 100, callbacks = [callback], batch_size = 32)

  test_loss, test_accuracy = model.evaluate(xtest, y[test])
  print("_________________________________________________________________________________________________________________________________")
  print("Test Accuracy:")
  print(test_accuracy)
  baseAccuracies.append(test_accuracy)
  print("_________________________________________________________________________________________________________________________________")
  print("Test Loss:")
  print(test_loss)
  losses.append(test_loss)
  print("_________________________________________________________________________________________________________________________________")
  preds = np.argmax(model.predict(xtest), axis=-1)
  preds = preds.reshape(len(xtest), 1)
  accs = []
  for cls in range(10):
    mask = (y[test] == cls)
    cls_acc = (preds == cls)[mask].mean() 
    accs.append(cls_acc)
  accs = np.mean(accs)
  print("Final balanced accuracy:")
  print(accs)
  balancedAccuracies.append(accs)
  print("_________________________________________________________________________________________________________________________________")
  f1scores.append(f1_score(y[test], preds, average = 'weighted'))
  precisions.append(precision_score(y[test], preds, average = 'weighted'))
  recalls.append(recall_score(y[test], preds, average = 'weighted'))
  print("*********************************************************************************************************************************")
  print()
  print()
# Out:
# _________________________________________________________________________________________________________________________________
# Fold number: 1
#
# Epoch 1/100
# 1969/1969 [==============================] - 78s 40ms/step - loss: 0.6498 - sparse_categorical_accuracy: 0.7902 - val_loss: 0.3202 - val_sparse_categorical_accuracy: 0.9023
# Epoch 2/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.1764 - sparse_categorical_accuracy: 0.9451 - val_loss: 0.1849 - val_sparse_categorical_accuracy: 0.9437
# Epoch 3/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0983 - sparse_categorical_accuracy: 0.9693 - val_loss: 0.0974 - val_sparse_categorical_accuracy: 0.9717
# Epoch 4/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0702 - sparse_categorical_accuracy: 0.9783 - val_loss: 0.1318 - val_sparse_categorical_accuracy: 0.9650
# Epoch 5/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0534 - sparse_categorical_accuracy: 0.9838 - val_loss: 0.0772 - val_sparse_categorical_accuracy: 0.9796
# Epoch 6/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0416 - sparse_categorical_accuracy: 0.9872 - val_loss: 0.0955 - val_sparse_categorical_accuracy: 0.9724
# Epoch 7/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0335 - sparse_categorical_accuracy: 0.9894 - val_loss: 0.0745 - val_sparse_categorical_accuracy: 0.9803
# Epoch 8/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0284 - sparse_categorical_accuracy: 0.9908 - val_loss: 0.0675 - val_sparse_categorical_accuracy: 0.9804
# Epoch 9/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0221 - sparse_categorical_accuracy: 0.9932 - val_loss: 0.0637 - val_sparse_categorical_accuracy: 0.9843
# Epoch 10/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0187 - sparse_categorical_accuracy: 0.9943 - val_loss: 0.0828 - val_sparse_categorical_accuracy: 0.9809
# Epoch 11/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0171 - sparse_categorical_accuracy: 0.9950 - val_loss: 0.0542 - val_sparse_categorical_accuracy: 0.9864
# Epoch 12/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0153 - sparse_categorical_accuracy: 0.9947 - val_loss: 0.0613 - val_sparse_categorical_accuracy: 0.9844
# Epoch 13/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0129 - sparse_categorical_accuracy: 0.9962 - val_loss: 0.0479 - val_sparse_categorical_accuracy: 0.9869
# Epoch 14/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0116 - sparse_categorical_accuracy: 0.9967 - val_loss: 0.1140 - val_sparse_categorical_accuracy: 0.9729
# Epoch 15/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0110 - sparse_categorical_accuracy: 0.9967 - val_loss: 0.0608 - val_sparse_categorical_accuracy: 0.9843
# Epoch 00015: early stopping
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0608 - sparse_categorical_accuracy: 0.9843
# _________________________________________________________________________________________________________________________________
# Test Accuracy:
# 0.9842857122421265
# _________________________________________________________________________________________________________________________________
# Test Loss:
# 0.060778114944696426
# _________________________________________________________________________________________________________________________________
# Final balanced accuracy:
# 0.9844348130582328
# _________________________________________________________________________________________________________________________________
# *********************************************************************************************************************************
#
#
# _________________________________________________________________________________________________________________________________
# Fold number: 2
#
# Epoch 1/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.6711 - sparse_categorical_accuracy: 0.7800 - val_loss: 0.2453 - val_sparse_categorical_accuracy: 0.9191
# Epoch 2/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.1803 - sparse_categorical_accuracy: 0.9438 - val_loss: 0.1426 - val_sparse_categorical_accuracy: 0.9539
# Epoch 3/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.1037 - sparse_categorical_accuracy: 0.9684 - val_loss: 0.0818 - val_sparse_categorical_accuracy: 0.9740
# Epoch 4/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0719 - sparse_categorical_accuracy: 0.9781 - val_loss: 0.1065 - val_sparse_categorical_accuracy: 0.9663
# Epoch 5/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0527 - sparse_categorical_accuracy: 0.9832 - val_loss: 0.0869 - val_sparse_categorical_accuracy: 0.9770
# Epoch 00005: early stopping
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0869 - sparse_categorical_accuracy: 0.9770
# _________________________________________________________________________________________________________________________________
# Test Accuracy:
# 0.9769999980926514
# _________________________________________________________________________________________________________________________________
# Test Loss:
# 0.08685720711946487
# _________________________________________________________________________________________________________________________________
# Final balanced accuracy:
# 0.9769020649009823
# _________________________________________________________________________________________________________________________________
# *********************************************************************************************************************************
#
#
# _________________________________________________________________________________________________________________________________
# Fold number: 3
#
# Epoch 1/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.6835 - sparse_categorical_accuracy: 0.7768 - val_loss: 0.2704 - val_sparse_categorical_accuracy: 0.9129
# Epoch 2/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.1740 - sparse_categorical_accuracy: 0.9460 - val_loss: 0.1217 - val_sparse_categorical_accuracy: 0.9599
# Epoch 3/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0987 - sparse_categorical_accuracy: 0.9695 - val_loss: 0.1394 - val_sparse_categorical_accuracy: 0.9579
# Epoch 4/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0705 - sparse_categorical_accuracy: 0.9785 - val_loss: 0.0983 - val_sparse_categorical_accuracy: 0.9730
# Epoch 5/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0553 - sparse_categorical_accuracy: 0.9830 - val_loss: 0.0666 - val_sparse_categorical_accuracy: 0.9810
# Epoch 6/100
# 1969/1969 [==============================] - 76s 39ms/step - loss: 0.0424 - sparse_categorical_accuracy: 0.9868 - val_loss: 0.1153 - val_sparse_categorical_accuracy: 0.9696
# Epoch 7/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0370 - sparse_categorical_accuracy: 0.9889 - val_loss: 0.0789 - val_sparse_categorical_accuracy: 0.9784
# Epoch 00007: early stopping
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0789 - sparse_categorical_accuracy: 0.9784
# _________________________________________________________________________________________________________________________________
# Test Accuracy:
# 0.9784285426139832
# _________________________________________________________________________________________________________________________________
# Test Loss:
# 0.07894719392061234
# _________________________________________________________________________________________________________________________________
# Final balanced accuracy:
# 0.978416574700477
# _________________________________________________________________________________________________________________________________
# *********************************************************************************************************************************
#
#
# _________________________________________________________________________________________________________________________________
# Fold number: 4
#
# Epoch 1/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.6635 - sparse_categorical_accuracy: 0.7821 - val_loss: 0.2905 - val_sparse_categorical_accuracy: 0.9096
# Epoch 2/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.1794 - sparse_categorical_accuracy: 0.9443 - val_loss: 0.1636 - val_sparse_categorical_accuracy: 0.9517
# Epoch 3/100
# 1969/1969 [==============================] - 76s 39ms/step - loss: 0.0992 - sparse_categorical_accuracy: 0.9693 - val_loss: 0.1377 - val_sparse_categorical_accuracy: 0.9603
# Epoch 4/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0733 - sparse_categorical_accuracy: 0.9773 - val_loss: 0.0936 - val_sparse_categorical_accuracy: 0.9721
# Epoch 5/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0552 - sparse_categorical_accuracy: 0.9832 - val_loss: 0.0874 - val_sparse_categorical_accuracy: 0.9739
# Epoch 6/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0413 - sparse_categorical_accuracy: 0.9871 - val_loss: 0.0824 - val_sparse_categorical_accuracy: 0.9753
# Epoch 7/100
# 1969/1969 [==============================] - 76s 39ms/step - loss: 0.0354 - sparse_categorical_accuracy: 0.9888 - val_loss: 0.0841 - val_sparse_categorical_accuracy: 0.9776
# Epoch 8/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0267 - sparse_categorical_accuracy: 0.9918 - val_loss: 0.0891 - val_sparse_categorical_accuracy: 0.9757
# Epoch 00008: early stopping
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0891 - sparse_categorical_accuracy: 0.9757
# _________________________________________________________________________________________________________________________________
# Test Accuracy:
# 0.9757142663002014
# _________________________________________________________________________________________________________________________________
# Test Loss:
# 0.08910944312810898
# _________________________________________________________________________________________________________________________________
# Final balanced accuracy:
# 0.9755370582608045
# _________________________________________________________________________________________________________________________________
# *********************************************************************************************************************************
#
#
# _________________________________________________________________________________________________________________________________
# Fold number: 5
#
# Epoch 1/100
# 1969/1969 [==============================] - 78s 39ms/step - loss: 0.6331 - sparse_categorical_accuracy: 0.7940 - val_loss: 0.3169 - val_sparse_categorical_accuracy: 0.8991
# Epoch 2/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.1714 - sparse_categorical_accuracy: 0.9467 - val_loss: 0.1476 - val_sparse_categorical_accuracy: 0.9517
# Epoch 3/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0957 - sparse_categorical_accuracy: 0.9709 - val_loss: 0.0897 - val_sparse_categorical_accuracy: 0.9736
# Epoch 4/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0694 - sparse_categorical_accuracy: 0.9787 - val_loss: 0.1054 - val_sparse_categorical_accuracy: 0.9677
# Epoch 5/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0514 - sparse_categorical_accuracy: 0.9841 - val_loss: 0.1015 - val_sparse_categorical_accuracy: 0.9720
# Epoch 00005: early stopping
# 219/219 [==============================] - 3s 12ms/step - loss: 0.1015 - sparse_categorical_accuracy: 0.9720
# _________________________________________________________________________________________________________________________________
# Test Accuracy:
# 0.972000002861023
# _________________________________________________________________________________________________________________________________
# Test Loss:
# 0.10145143419504166
# _________________________________________________________________________________________________________________________________
# Final balanced accuracy:
# 0.972017098003984
# _________________________________________________________________________________________________________________________________
# *********************************************************************************************************************************
#
#
# _________________________________________________________________________________________________________________________________
# Fold number: 6
#
# Epoch 1/100
# 1969/1969 [==============================] - 78s 39ms/step - loss: 0.6729 - sparse_categorical_accuracy: 0.7807 - val_loss: 0.2840 - val_sparse_categorical_accuracy: 0.9121
# Epoch 2/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.1777 - sparse_categorical_accuracy: 0.9432 - val_loss: 0.1607 - val_sparse_categorical_accuracy: 0.9530
# Epoch 3/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.1014 - sparse_categorical_accuracy: 0.9683 - val_loss: 0.1207 - val_sparse_categorical_accuracy: 0.9663
# Epoch 4/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0681 - sparse_categorical_accuracy: 0.9785 - val_loss: 0.1123 - val_sparse_categorical_accuracy: 0.9696
# Epoch 5/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0562 - sparse_categorical_accuracy: 0.9832 - val_loss: 0.0736 - val_sparse_categorical_accuracy: 0.9799
# Epoch 6/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0426 - sparse_categorical_accuracy: 0.9868 - val_loss: 0.1267 - val_sparse_categorical_accuracy: 0.9629
# Epoch 7/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0364 - sparse_categorical_accuracy: 0.9889 - val_loss: 0.0655 - val_sparse_categorical_accuracy: 0.9823
# Epoch 8/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0266 - sparse_categorical_accuracy: 0.9918 - val_loss: 0.0795 - val_sparse_categorical_accuracy: 0.9807
# Epoch 9/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0221 - sparse_categorical_accuracy: 0.9932 - val_loss: 0.0615 - val_sparse_categorical_accuracy: 0.9840
# Epoch 10/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0206 - sparse_categorical_accuracy: 0.9939 - val_loss: 0.0503 - val_sparse_categorical_accuracy: 0.9857
# Epoch 11/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0173 - sparse_categorical_accuracy: 0.9947 - val_loss: 0.0593 - val_sparse_categorical_accuracy: 0.9841
# Epoch 12/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0137 - sparse_categorical_accuracy: 0.9957 - val_loss: 0.0575 - val_sparse_categorical_accuracy: 0.9870
# Epoch 00012: early stopping
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0575 - sparse_categorical_accuracy: 0.9870
# _________________________________________________________________________________________________________________________________
# Test Accuracy:
# 0.9869999885559082
# _________________________________________________________________________________________________________________________________
# Test Loss:
# 0.05750491842627525
# _________________________________________________________________________________________________________________________________
# Final balanced accuracy:
# 0.9870113979754878
# _________________________________________________________________________________________________________________________________
# *********************************************************************************************************************************
#
#
# _________________________________________________________________________________________________________________________________
# Fold number: 7
#
# Epoch 1/100
# 1969/1969 [==============================] - 78s 40ms/step - loss: 0.6383 - sparse_categorical_accuracy: 0.7926 - val_loss: 0.3079 - val_sparse_categorical_accuracy: 0.9037
# Epoch 2/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.1643 - sparse_categorical_accuracy: 0.9494 - val_loss: 0.2227 - val_sparse_categorical_accuracy: 0.9351
# Epoch 3/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0946 - sparse_categorical_accuracy: 0.9703 - val_loss: 0.1320 - val_sparse_categorical_accuracy: 0.9613
# Epoch 4/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0670 - sparse_categorical_accuracy: 0.9793 - val_loss: 0.0831 - val_sparse_categorical_accuracy: 0.9760
# Epoch 5/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0519 - sparse_categorical_accuracy: 0.9843 - val_loss: 0.0951 - val_sparse_categorical_accuracy: 0.9739
# Epoch 6/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0413 - sparse_categorical_accuracy: 0.9872 - val_loss: 0.0810 - val_sparse_categorical_accuracy: 0.9789
# Epoch 7/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0329 - sparse_categorical_accuracy: 0.9901 - val_loss: 0.0565 - val_sparse_categorical_accuracy: 0.9839
# Epoch 8/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0292 - sparse_categorical_accuracy: 0.9911 - val_loss: 0.0706 - val_sparse_categorical_accuracy: 0.9807
# Epoch 9/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0237 - sparse_categorical_accuracy: 0.9929 - val_loss: 0.0548 - val_sparse_categorical_accuracy: 0.9847
# Epoch 10/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0201 - sparse_categorical_accuracy: 0.9943 - val_loss: 0.0485 - val_sparse_categorical_accuracy: 0.9871
# Epoch 11/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0167 - sparse_categorical_accuracy: 0.9948 - val_loss: 0.0613 - val_sparse_categorical_accuracy: 0.9847
# Epoch 12/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0158 - sparse_categorical_accuracy: 0.9951 - val_loss: 0.0449 - val_sparse_categorical_accuracy: 0.9879
# Epoch 13/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0127 - sparse_categorical_accuracy: 0.9961 - val_loss: 0.0533 - val_sparse_categorical_accuracy: 0.9849
# Epoch 14/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0159 - sparse_categorical_accuracy: 0.9951 - val_loss: 0.0523 - val_sparse_categorical_accuracy: 0.9846
# Epoch 00014: early stopping
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0523 - sparse_categorical_accuracy: 0.9846
# _________________________________________________________________________________________________________________________________
# Test Accuracy:
# 0.9845714569091797
# _________________________________________________________________________________________________________________________________
# Test Loss:
# 0.0522918775677681
# _________________________________________________________________________________________________________________________________
# Final balanced accuracy:
# 0.9845113635277798
# _________________________________________________________________________________________________________________________________
# *********************************************************************************************************************************
#
#
# _________________________________________________________________________________________________________________________________
# Fold number: 8
#
# Epoch 1/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.6623 - sparse_categorical_accuracy: 0.7867 - val_loss: 0.2812 - val_sparse_categorical_accuracy: 0.9143
# Epoch 2/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.1778 - sparse_categorical_accuracy: 0.9452 - val_loss: 0.1407 - val_sparse_categorical_accuracy: 0.9567
# Epoch 3/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.1015 - sparse_categorical_accuracy: 0.9681 - val_loss: 0.1274 - val_sparse_categorical_accuracy: 0.9623
# Epoch 4/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0716 - sparse_categorical_accuracy: 0.9781 - val_loss: 0.0989 - val_sparse_categorical_accuracy: 0.9720
# Epoch 5/100
# 1969/1969 [==============================] - 76s 39ms/step - loss: 0.0552 - sparse_categorical_accuracy: 0.9827 - val_loss: 0.1040 - val_sparse_categorical_accuracy: 0.9716
# Epoch 6/100
# 1969/1969 [==============================] - 76s 39ms/step - loss: 0.0423 - sparse_categorical_accuracy: 0.9866 - val_loss: 0.0953 - val_sparse_categorical_accuracy: 0.9713
# Epoch 7/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0353 - sparse_categorical_accuracy: 0.9895 - val_loss: 0.0581 - val_sparse_categorical_accuracy: 0.9841
# Epoch 8/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0292 - sparse_categorical_accuracy: 0.9908 - val_loss: 0.0545 - val_sparse_categorical_accuracy: 0.9847
# Epoch 9/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0223 - sparse_categorical_accuracy: 0.9929 - val_loss: 0.0562 - val_sparse_categorical_accuracy: 0.9844
# Epoch 10/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0193 - sparse_categorical_accuracy: 0.9943 - val_loss: 0.0653 - val_sparse_categorical_accuracy: 0.9823
# Epoch 00010: early stopping
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0653 - sparse_categorical_accuracy: 0.9823
# _________________________________________________________________________________________________________________________________
# Test Accuracy:
# 0.982285737991333
# _________________________________________________________________________________________________________________________________
# Test Loss:
# 0.06527283787727356
# _________________________________________________________________________________________________________________________________
# Final balanced accuracy:
# 0.9821856174851986
# _________________________________________________________________________________________________________________________________
# *********************************************************************************************************************************
#
#
# _________________________________________________________________________________________________________________________________
# Fold number: 9
#
# Epoch 1/100
# 1969/1969 [==============================] - 78s 39ms/step - loss: 0.6754 - sparse_categorical_accuracy: 0.7792 - val_loss: 0.2968 - val_sparse_categorical_accuracy: 0.9043
# Epoch 2/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.1747 - sparse_categorical_accuracy: 0.9452 - val_loss: 0.1662 - val_sparse_categorical_accuracy: 0.9500
# Epoch 3/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0976 - sparse_categorical_accuracy: 0.9692 - val_loss: 0.1131 - val_sparse_categorical_accuracy: 0.9676
# Epoch 4/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0716 - sparse_categorical_accuracy: 0.9777 - val_loss: 0.1057 - val_sparse_categorical_accuracy: 0.9671
# Epoch 5/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0522 - sparse_categorical_accuracy: 0.9839 - val_loss: 0.1022 - val_sparse_categorical_accuracy: 0.9697
# Epoch 6/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0434 - sparse_categorical_accuracy: 0.9868 - val_loss: 0.0890 - val_sparse_categorical_accuracy: 0.9756
# Epoch 7/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0352 - sparse_categorical_accuracy: 0.9892 - val_loss: 0.0857 - val_sparse_categorical_accuracy: 0.9760
# Epoch 8/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0270 - sparse_categorical_accuracy: 0.9918 - val_loss: 0.0780 - val_sparse_categorical_accuracy: 0.9801
# Epoch 9/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0232 - sparse_categorical_accuracy: 0.9929 - val_loss: 0.0795 - val_sparse_categorical_accuracy: 0.9797
# Epoch 10/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0187 - sparse_categorical_accuracy: 0.9940 - val_loss: 0.0661 - val_sparse_categorical_accuracy: 0.9837
# Epoch 11/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0163 - sparse_categorical_accuracy: 0.9943 - val_loss: 0.0601 - val_sparse_categorical_accuracy: 0.9866
# Epoch 12/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0166 - sparse_categorical_accuracy: 0.9953 - val_loss: 0.3435 - val_sparse_categorical_accuracy: 0.9427
# Epoch 13/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0160 - sparse_categorical_accuracy: 0.9954 - val_loss: 0.0767 - val_sparse_categorical_accuracy: 0.9799
# Epoch 00013: early stopping
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0767 - sparse_categorical_accuracy: 0.9799
# _________________________________________________________________________________________________________________________________
# Test Accuracy:
# 0.9798571467399597
# _________________________________________________________________________________________________________________________________
# Test Loss:
# 0.07670717686414719
# _________________________________________________________________________________________________________________________________
# Final balanced accuracy:
# 0.9797713146089435
# _________________________________________________________________________________________________________________________________
# *********************************************************************************************************************************
#
#
# _________________________________________________________________________________________________________________________________
# Fold number: 10
#
# Epoch 1/100
# 1969/1969 [==============================] - 78s 39ms/step - loss: 0.6850 - sparse_categorical_accuracy: 0.7760 - val_loss: 0.3483 - val_sparse_categorical_accuracy: 0.8877
# Epoch 2/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.1785 - sparse_categorical_accuracy: 0.9446 - val_loss: 0.1474 - val_sparse_categorical_accuracy: 0.9549
# Epoch 3/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0983 - sparse_categorical_accuracy: 0.9694 - val_loss: 0.1070 - val_sparse_categorical_accuracy: 0.9691
# Epoch 4/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0694 - sparse_categorical_accuracy: 0.9784 - val_loss: 0.0956 - val_sparse_categorical_accuracy: 0.9719
# Epoch 5/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0537 - sparse_categorical_accuracy: 0.9834 - val_loss: 0.1021 - val_sparse_categorical_accuracy: 0.9737
# Epoch 6/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0449 - sparse_categorical_accuracy: 0.9855 - val_loss: 0.0652 - val_sparse_categorical_accuracy: 0.9821
# Epoch 7/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0351 - sparse_categorical_accuracy: 0.9892 - val_loss: 0.0681 - val_sparse_categorical_accuracy: 0.9820
# Epoch 8/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0275 - sparse_categorical_accuracy: 0.9915 - val_loss: 0.0559 - val_sparse_categorical_accuracy: 0.9846
# Epoch 9/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0222 - sparse_categorical_accuracy: 0.9928 - val_loss: 0.0955 - val_sparse_categorical_accuracy: 0.9809
# Epoch 10/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0206 - sparse_categorical_accuracy: 0.9937 - val_loss: 0.0483 - val_sparse_categorical_accuracy: 0.9876
# Epoch 11/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0182 - sparse_categorical_accuracy: 0.9946 - val_loss: 0.0452 - val_sparse_categorical_accuracy: 0.9886
# Epoch 12/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0137 - sparse_categorical_accuracy: 0.9956 - val_loss: 0.0362 - val_sparse_categorical_accuracy: 0.9909
# Epoch 13/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0119 - sparse_categorical_accuracy: 0.9964 - val_loss: 0.0799 - val_sparse_categorical_accuracy: 0.9823
# Epoch 14/100
# 1969/1969 [==============================] - 77s 39ms/step - loss: 0.0126 - sparse_categorical_accuracy: 0.9964 - val_loss: 0.0516 - val_sparse_categorical_accuracy: 0.9880
# Epoch 00014: early stopping
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0516 - sparse_categorical_accuracy: 0.9880
# _________________________________________________________________________________________________________________________________
# Test Accuracy:
# 0.9879999756813049
# _________________________________________________________________________________________________________________________________
# Test Loss:
# 0.0516398623585701
# _________________________________________________________________________________________________________________________________
# Final balanced accuracy:
# 0.9880114144366743
# _________________________________________________________________________________________________________________________________
# *********************************************************************************************************************************

# %%
print('------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(balancedAccuracies)):
  print('------------------------------------------------------------------------')
  print(f'> Fold {i+1} - Loss: {losses[i]} - class-wise Accuracy: {balancedAccuracies[i]}% Accuracy - {baseAccuracies[i]} - Precision: {precisions[i]} - Recall: {recalls[i]} - F1: {f1scores[i]}')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> Accuracy: {np.mean(balancedAccuracies)} (+- {np.std(balancedAccuracies)})')
print(f'> Loss: {np.mean(losses)}')
print('------------------------------------------------------------------------')
# Out:
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 0.060778114944696426 - class-wise Accuracy: 0.9844348130582328% Accuracy - 0.9842857122421265 - Precision: 0.9843628774909046 - Recall: 0.9842857142857143 - F1: 0.9842797568888869
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 0.08685720711946487 - class-wise Accuracy: 0.9769020649009823% Accuracy - 0.9769999980926514 - Precision: 0.9776268293349725 - Recall: 0.977 - F1: 0.9770122790752899
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 0.07894719392061234 - class-wise Accuracy: 0.978416574700477% Accuracy - 0.9784285426139832 - Precision: 0.9788230700519056 - Recall: 0.9784285714285714 - F1: 0.9784773703037818
# ------------------------------------------------------------------------
# > Fold 4 - Loss: 0.08910944312810898 - class-wise Accuracy: 0.9755370582608045% Accuracy - 0.9757142663002014 - Precision: 0.9759497671437564 - Recall: 0.9757142857142858 - F1: 0.9755834220972014
# ------------------------------------------------------------------------
# > Fold 5 - Loss: 0.10145143419504166 - class-wise Accuracy: 0.972017098003984% Accuracy - 0.972000002861023 - Precision: 0.9724476255141948 - Recall: 0.972 - F1: 0.9720079820882455
# ------------------------------------------------------------------------
# > Fold 6 - Loss: 0.05750491842627525 - class-wise Accuracy: 0.9870113979754878% Accuracy - 0.9869999885559082 - Precision: 0.9870193211725191 - Recall: 0.987 - F1: 0.9869956198038691
# ------------------------------------------------------------------------
# > Fold 7 - Loss: 0.0522918775677681 - class-wise Accuracy: 0.9845113635277798% Accuracy - 0.9845714569091797 - Precision: 0.9847155674985355 - Recall: 0.9845714285714285 - F1: 0.984590706686755
# ------------------------------------------------------------------------
# > Fold 8 - Loss: 0.06527283787727356 - class-wise Accuracy: 0.9821856174851986% Accuracy - 0.982285737991333 - Precision: 0.9824367488302606 - Recall: 0.9822857142857143 - F1: 0.9823015803546428
# ------------------------------------------------------------------------
# > Fold 9 - Loss: 0.07670717686414719 - class-wise Accuracy: 0.9797713146089435% Accuracy - 0.9798571467399597 - Precision: 0.9800626266404475 - Recall: 0.9798571428571429 - F1: 0.979858733193082
# ------------------------------------------------------------------------
# > Fold 10 - Loss: 0.0516398623585701 - class-wise Accuracy: 0.9880114144366743% Accuracy - 0.9879999756813049 - Precision: 0.9880482660061591 - Recall: 0.988 - F1: 0.9880030218382884
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 0.9808798716958563 (+- 0.004961843610780389)
# > Loss: 0.07205600664019585
# ------------------------------------------------------------------------
